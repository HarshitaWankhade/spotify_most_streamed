# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O

# %%
data=pd.read_csv("Spotify Most Streamed Songs.csv")
data.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  key   mode  \
# ...

# %%
data.drop("cover_url",axis=1,inplace=True)
data.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
data.isnull().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# track_name              0
# artist(s)_name          0
# artist_count            0
# released_year           0
# released_month          0
# released_day            0
# in_spotify_playlists    0
# in_spotify_charts       0
# streams                 0
# in_apple_playlists      0
# in_apple_charts         0
# in_deezer_playlists     0
# in_deezer_charts        0
# in_shazam_charts        0
# bpm                     0
# key                     0
# mode                    0
# danceability_%          0
# valence_%               0
# energy_%                0
# acousticness_%          0
# instrumentalness_%      0
# liveness_%              0
# speechiness_%           0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
En=LabelEncoder()
Enco4=En.fit_transform(data["track_name"])
data.drop("track_name",axis=1,inplace=True)
data["track_name"]=Enco4

# %%
data.head()
# Out:
#      artist(s)_name  artist_count  released_year  released_month  \
# 0  Latto, Jung Kook             2           2023               7
# 1       Myke Towers             1           2023               3
# 2    Olivia Rodrigo             1           2023               6
# 3      Taylor Swift             1           2019               8
# 4         Bad Bunny             1           2023               5
#
#    released_day  in_spotify_playlists  in_spotify_charts    streams  \
# 0            14                   553                147  141381703
# 1            23                  1474                 48  133716286
# 2            30                  1397                113  140003974
# 3            23                  7858                100  800840817
# 4            18                  3133                 50  303236322
#
#    in_apple_playlists  in_apple_charts  ... key   mode danceability_%  \
# 0                  43              263  ...   B  Major             80
# ...

# %%
from sklearn.preprocessing import LabelEncoder
En=LabelEncoder()
Enco=En.fit_transform(data["artist(s)_name"]) 
data.drop("artist(s)_name",axis=1,inplace=True)
data["artist(s)_name"]=Enco

# %%
data.head()
# Out:
#    artist_count  released_year  released_month  released_day  \
# 0             2           2023               7            14
# 1             1           2023               3            23
# 2             1           2023               6            30
# 3             1           2019               8            23
# 4             1           2023               5            18
#
#    in_spotify_playlists  in_spotify_charts    streams  in_apple_playlists  \
# 0                   553                147  141381703                  43
# 1                  1474                 48  133716286                  48
# 2                  1397                113  140003974                  94
# 3                  7858                100  800840817                 116
# 4                  3133                 50  303236322                  84
#
#    in_apple_charts in_deezer_playlists  ...   mode danceability_%  valence_%  \
# ...

# %%
data.dtypes
# Out:
# artist_count             int64
# released_year            int64
# released_month           int64
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                 object
# in_apple_playlists       int64
# in_apple_charts          int64
# in_deezer_playlists     object
# in_deezer_charts         int64
# in_shazam_charts        object
# bpm                      int64
# key                     object
# mode                    object
# danceability_%           int64
# valence_%                int64
# energy_%                 int64
# acousticness_%           int64
# instrumentalness_%       int64
# liveness_%               int64
# speechiness_%            int64
# track_name               int32
# artist(s)_name           int32
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
En=LabelEncoder()
Enco1=En.fit_transform(data["streams"]) 
data.drop("streams",axis=1,inplace=True)
data["streams"]=Enco1

# %%
from sklearn.preprocessing import LabelEncoder
En=LabelEncoder()
Enco2=En.fit_transform(data["in_deezer_playlists"]) 
data.drop("in_deezer_playlists",axis=1,inplace=True)
data["in_deezer_playlists"]=Enco2

# %%
from sklearn.preprocessing import LabelEncoder
En=LabelEncoder()
Enco3=En.fit_transform(data["in_shazam_charts"]) 
data.drop("in_shazam_charts",axis=1,inplace=True)
data["in_shazam_charts"]=Enco3

# %%
from sklearn.preprocessing import LabelEncoder
En=LabelEncoder()
Enco5=En.fit_transform(data["key"]) 
data.drop("key",axis=1,inplace=True)
data["key"]=Enco5

# %%
from sklearn.preprocessing import LabelEncoder
En=LabelEncoder()
Enco6=En.fit_transform(data["mode"]) 
data.drop("mode",axis=1,inplace=True)
data["mode"]=Enco6

# %%
data.dtypes
# Out:
# artist_count            int64
# released_year           int64
# released_month          int64
# released_day            int64
# in_spotify_playlists    int64
# in_spotify_charts       int64
# in_apple_playlists      int64
# in_apple_charts         int64
# in_deezer_charts        int64
# bpm                     int64
# danceability_%          int64
# valence_%               int64
# energy_%                int64
# acousticness_%          int64
# instrumentalness_%      int64
# liveness_%              int64
# speechiness_%           int64
# track_name              int32
# artist(s)_name          int32
# streams                 int32
# in_deezer_playlists     int32
# in_shazam_charts        int64
# key                     int64
# mode                    int64
# dtype: object

# %%
corr_data1=data.corr()

# %%
data.drop("artist(s)_name",axis=1,inplace=True)
data.head()
# Out:
#    artist_count  released_year  released_month  released_day  \
# 0             2           2023               7            14
# 1             1           2023               3            23
# 2             1           2023               6            30
# 3             1           2019               8            23
# 4             1           2023               5            18
#
#    in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# 0                   553                147                  43
# 1                  1474                 48                  48
# 2                  1397                113                  94
# 3                  7858                100                 116
# 4                  3133                 50                  84
#
#    in_apple_charts  in_deezer_charts  bpm  ...  acousticness_%  \
# 0              263                10  125  ...              31
# 1              126                14   92  ...               7
# ...

# %%
data2=data.drop("track_name",axis=1)
data2.head()
# Out:
#    artist_count  released_year  released_month  released_day  \
# 0             2           2023               7            14
# 1             1           2023               3            23
# 2             1           2023               6            30
# 3             1           2019               8            23
# 4             1           2023               5            18
#
#    in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# 0                   553                147                  43
# 1                  1474                 48                  48
# 2                  1397                113                  94
# 3                  7858                100                 116
# 4                  3133                 50                  84
#
#    in_apple_charts  in_deezer_charts  bpm  ...  energy_%  acousticness_%  \
# 0              263                10  125  ...        83              31
# ...

# %%
data.corr()
# Out:
#                       artist_count  released_year  released_month  \
# artist_count              1.000000       0.073564        0.033857
# released_year             0.073564       1.000000        0.076439
# released_month            0.033857       0.076439        1.000000
# released_day             -0.014762       0.166377        0.057784
# in_spotify_playlists     -0.085226      -0.390729       -0.122407
# in_spotify_charts        -0.008570       0.068679       -0.050186
# in_apple_playlists       -0.017024      -0.201474       -0.034029
# in_apple_charts          -0.075271       0.003479       -0.017813
# in_deezer_charts          0.020585       0.095741        0.006942
# bpm                      -0.058844      -0.011570       -0.049400
# danceability_%            0.214078       0.215032       -0.054808
# valence_%                 0.123650      -0.047643       -0.110355
# energy_%                  0.137530       0.078886       -0.086897
# ...

# %%
import seaborn as sns
cor_data=data2.corr()

# %%
sns.heatmap(corr_data1)
# Out:
# <Axes: >

# %%
sns.heatmap(cor_data)
# Out:
# <Axes: >

# %%
list(data2)
# Out:
# ['artist_count',
#  'released_year',
#  'released_month',
#  'released_day',
#  'in_spotify_playlists',
#  'in_spotify_charts',
#  'in_apple_playlists',
#  'in_apple_charts',
#  'in_deezer_charts',
#  'bpm',
#  'danceability_%',
#  'valence_%',
#  'energy_%',
#  'acousticness_%',
#  'instrumentalness_%',
#  'liveness_%',
#  'speechiness_%',
#  'streams',
#  'in_deezer_playlists',
#  'in_shazam_charts',
#  'key',
#  'mode']

# %%
data2_col=['artist_count',
 'released_year',
 'released_month',
 'released_day',
 'in_spotify_charts',
 'in_apple_playlists',
 'in_apple_charts',
 'in_deezer_charts',
 'bpm',
 'danceability_%',
 'valence_%',
 'energy_%',
 'acousticness_%',
 'instrumentalness_%',
 'liveness_%',
 'speechiness_%',
 'streams',
 'in_deezer_playlists',
 'in_shazam_charts',
 'key',
 'mode','in_spotify_playlists']

# %%
data2 = data2.reindex(columns=data2_col)

# %%
data2.head()
# Out:
#    artist_count  released_year  released_month  released_day  \
# 0             2           2023               7            14
# 1             1           2023               3            23
# 2             1           2023               6            30
# 3             1           2019               8            23
# 4             1           2023               5            18
#
#    in_spotify_charts  in_apple_playlists  in_apple_charts  in_deezer_charts  \
# 0                147                  43              263                10
# 1                 48                  48              126                14
# 2                113                  94              207                14
# 3                100                 116              207                12
# 4                 50                  84              133                15
#
#    bpm  danceability_%  ...  acousticness_%  instrumentalness_%  liveness_%  \
# ...

# %%
X=data2.iloc[:,:-1]
X.head(9)
# Out:
#    artist_count  released_year  released_month  released_day  \
# 0             2           2023               7            14
# 1             1           2023               3            23
# 2             1           2023               6            30
# 3             1           2019               8            23
# 4             1           2023               5            18
# 5             2           2023               6             1
# 6             2           2023               3            16
# 7             1           2023               7             7
# 8             1           2023               5            15
#
#    in_spotify_charts  in_apple_playlists  in_apple_charts  in_deezer_charts  \
# 0                147                  43              263                10
# 1                 48                  48              126                14
# 2                113                  94              207                14
# ...

# %%
list(X)
# Out:
# ['artist_count',
#  'released_year',
#  'released_month',
#  'released_day',
#  'in_spotify_charts',
#  'in_apple_playlists',
#  'in_apple_charts',
#  'in_deezer_charts',
#  'bpm',
#  'danceability_%',
#  'valence_%',
#  'energy_%',
#  'acousticness_%',
#  'instrumentalness_%',
#  'liveness_%',
#  'speechiness_%',
#  'streams',
#  'in_deezer_playlists',
#  'in_shazam_charts',
#  'key',
#  'mode']

# %%
y=data2.iloc[:,-1:]
y.head(9)
# Out:
#    in_spotify_playlists
# 0                   553
# 1                  1474
# 2                  1397
# 3                  7858
# 4                  3133
# 5                  2186
# 6                  3090
# 7                   714
# 8                  1096

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=27,random_state=42)
from sklearn.tree import DecisionTreeRegressor

model=DecisionTreeRegressor(random_state=42)
model.fit(X,y)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
from sklearn.metrics import accuracy_score

ac_test=model.score(X_test,y_test)
ac_train=model.score(X_train,y_train)

print(ac_test,ac_train)
# Out:
# 1.0 1.0

# %%
X_new=X.iloc[2]

# %%
prediction=model.predict([X_new])
print(prediction)
# Out:
# [1397.]
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
my_line=np.array([3,2023,10,9,57,48,49,52,126,82,78,83,71,67,80,8,627,275,127,4,1])

# %%
my_prediction=model.predict([my_line])
print(my_prediction)
# Out:
# [864.]
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
